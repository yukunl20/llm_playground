# %%
from sec_edgar_downloader import Downloader

# %%
dl = Downloader("Abner Liu", "abnerl2021@gmail.com", "/Users/yukunliu/Desktop/LLM_playground/10-K/SNDK")
dl.get("10-K", "SNDK", limit=5)
# Out:
# 1
